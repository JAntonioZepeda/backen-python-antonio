# %%
print("Carrito de compras\n")
print("""
Productos Disponibles:
1.- Playeras
2.- Camisas
3.- Pantalones
4.- Shorts
5.- Chamarras
6.- Sudaderas
7.- Sueters
8.- Gorras
""")
print("Ingresa una lista con los productos en este formato: [[Cantidad,Producto]]")
print("Por ejemplo: [[1,1], [3,2]] significa 1 Playera y 3 pantalones" )

my_shopping_cart = eval(input())

print("\n\n Tu carrito es:")
if type(my_shopping_cart)== list:
    if type(my_shopping_cart[0])==list:
        for element in my_shopping_cart:
            product=""
            if element[1]==1:
                product="Playeras"
            if element[1]==2:
                product="Camisas"
            if element[1]==3:
                product="Pantalones"
            if element[1]==4:
                product="Shorts"
            if element[1]==5:
                product="Chamarras"
            if element[1]==6:
                product="Sudaderas"
            if element[1]==7:
                product="sueters"
            if element[1]==8:
                product="Gorras"
        
            print("{} {}".format(element[0],product))
    else:
        print("Formato incorrecto, debese de ingresar una lista de listas")

else:
    print("Formato incorrecto, debese de ingresar una lista de listas")
# Out:
# Carrito de compras
#
#
# Productos Disponibles:
# 1.- Playeras
# 2.- Camisas
# 3.- Pantalones
# 4.- Shorts
# 5.- Chamarras
# 6.- Sudaderas
# 7.- Sueters
# 8.- Gorras
#
# Ingresa una lista con los productos en este formato: [[Cantidad,Producto]]
# Por ejemplo: [[1,1], [3,2]] significa 1 Playera y 3 pantalones
# [[5,1],[2,2],[3,3],[1,4],[3,5],[2,6],[3,7],[5,8]]
#
#
#  Tu carrito es:
# 5 Playeras
# 2 Camisas
# 3 Pantalones
# 1 Shorts
# 3 Chamarras
# 2 Sudaderas
# 3 sueters
# 5 Gorras
